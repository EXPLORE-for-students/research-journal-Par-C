# %% [markdown]
# # Research Notebook
# ## Partik Chahal
# ## Date: March 10 2025

# %% [markdown]
# # 1: Experience
# ## Describe at least one research activity you worked on this week.
#
# - Ran simulations on with various minimum wind velocity, wind energy, and radiative efficiency of black hole factors
# - Compiled and binned group data, along with data from the previous time to create various plots showing the effect of the changes
#
#
# ## Motivation:
#
# The purpose of these changes is to check if the black holes are able to more massive, and explain how at high redshift, the masses of these black holes exceed expectations. When changing the Eddington factor to higher values, we are letting accrete higher than the Eddington limit, allowing them to grow more massive. When changing their wind velocity to lower values, we are letting more gas to stay in the galaxy, also allowing the black holes to grow further. When changing the wind energy to lower factors, we are allowing to lower energy outflows, allowing less gas to be expelled from the galaxy. Lowering the radiative efficiency is lowers the amount of energy radiated away by the black holes from the mass it accretes.

# %% [markdown]
# # 2: What? (What happened?)
# ## Describe what happened during your activities for the week.
#
# Each group member was responsible for a different value for each of the changed parameters. When each simulation was finished, we shared the directories and used it to plot after binning the data. Different binning techniques were used, equal bin sizes (which had the effect of having no error bars on some of the points), and equal points in equal bins. The Eddington factor changes employed a equal points in equal bins binning method, and the others equal spacing bins.
#
# For the Eddington factor changes:
#
# ![bh_mass_vs_stellar_mass_log_bins.png](attachment:611733d4-f9a8-4173-9158-0efc029ec18c.png)
#
# ![halo_mass_vs_stellar_mass_log_bins.png](attachment:031d6896-d9a5-4890-9c70-58b4e9e84274.png)
#
#
# For the wind velocity changes:
#
# ![stellar_vs_bh_mass_diff_MWVs2.png](attachment:b55a2490-f7e3-475a-b5f6-428198bc6a76.png)
#
# ![stellar_vs_halo_mass_diff_MWVs2.png](attachment:30cd0ad0-2bbf-48cd-862c-61f2df7a5220.png)
#
#
# For the wind energy changes:
#
# ![stellar_vs_bh_mass_diff_WEFs2.png](attachment:21421e25-2e46-4f0e-9396-64994ec7b1f7.png)
#
# ![stellar_vs_halo_mass_diff_WEFs2.png](attachment:5fd636db-9878-413a-a2c0-f2ae8b3afc5c.png)
#
# For the radiative efficiency changes:
#
# ![bh_mass_vs_stellar_mass_bheff.png](attachment:08d4833e-b927-4a0b-9064-a80cf2fd104a.png)
#
# ![halo_mass_vs_stellar_mass_bheff.png](attachment:3eeeeee6-abb6-4db9-9edc-a7f6ac85a892.png)

# %% [markdown]
# # 3: So what? (What does it mean?)
# ## Describe your results
#
# It is difficult to notice a difference in the trends for the radiative efficiency changes. It does show however, that the default value (0.2) shows less massive black holes with higher stellar masses, when compared to lower radiative efficiencies. This could mean that the lower radiative efficiency factors allow for less of the mass that the black hole is accreting to be radiated away. For the higher Eddington factor changes (changing EF to 2 and 3 resulted in overlapped data), there are higher (yellow points) black hole masses, which shows that allowing for the black holes to accrete more than the eddington limit allows for the black holes to become more massive. For the wind energy and minimum wind velocity changes (changing MWV to 50 and 200 resulted in overlapped data), lowering these factors does not seem to cause a definitive change compared to the original values. The result is that the changes in the Eddington factor and radiative efficiency do create these more massive black holes.

# %% [markdown]
# # 4. Now what? (What's next?)
# ## Plan for the next week
#
# The plan for the next meeting is to change the parameter files to allow for redshift = 6, 3, 2, 1 and run the simulations, and plot the same graphs as above at these different red shifts using equal points in each bin. Since there was trouble with Gadget4 and that is been fixed today (since the meeting is every Monday), we will run sample simulations on Gadget4 before altering them next week.

# %% [markdown]
# # 5. Bibliography
#
# Your references here

# %%
(2) Pacucci, F., Loeb, A., & Grazian, A. (2023). The Black Hole Mass–Stellar Mass Relation of High-redshift Galaxies: A Theoretical Prediction to z ≈ 10. 
The Astrophysical Journal, 944(1), 1. https://doi.org/10.3847/1538-4357/ad3044
